# %%
from __future__ import print_function, division
import os
import torch
import pandas as pd
from skimage import io, transform
import numpy as np
import matplotlib.pyplot as plt
from torch.utils.data import Dataset, DataLoader
from torchvision import transforms, utils, datasets, models

# Ignore warnings
import warnings
warnings.filterwarnings("ignore")
import os
os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID"   # see issue #152
os.environ["CUDA_VISIBLE_DEVICES"]="0"

# %%
#from lib import RadioUNet_modules3, RadioUNet_loaders2
from lib import loaders, modules

# %% [markdown]
# ## Dataset Loader, RadioUNetc threshold=0.2

# %%
Radio_train = loaders.RadioUNet_s(phase="train", simulation="rand", cityMap="missing", missing=4)
Radio_val = loaders.RadioUNet_s(phase="val", simulation="rand", cityMap="missing", missing=4)
Radio_test = loaders.RadioUNet_s(phase="test", simulation="rand", cityMap="missing", missing=4)

image_datasets = {
    'train': Radio_train, 'val': Radio_val
}

batch_size = 15

dataloaders = {
    'train': DataLoader(Radio_train, batch_size=batch_size, shuffle=True, num_workers=1),
    'val': DataLoader(Radio_val, batch_size=batch_size, shuffle=True, num_workers=1)
}

# %% [markdown]
# ## Test Sample Image

# %%
i=1000
image_build_ant, image_gain = Radio_train[i]
plt.imshow(image_gain[0])

# %%
i=1000
image_build_ant, image_gain = Radio_train[i]
plt.imshow(image_build_ant[2])

# %% [markdown]
# ## Load Model and Summary

# %%
from torchsummary import summary

torch.set_default_dtype(torch.float32)
torch.set_default_tensor_type('torch.cuda.FloatTensor')
torch.backends.cudnn.enabled
model =modules.RadioWNet(inputs=3, phase="firstU")
model.cuda()
summary(model, input_size=(3, 256,256))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ...
#             Conv2d-1          [-1, 6, 256, 256]             168
#               ReLU-2          [-1, 6, 256, 256]               0
#          MaxPool2d-3          [-1, 6, 256, 256]               0
#             Conv2d-4         [-1, 40, 256, 256]           6,040
#               ReLU-5         [-1, 40, 256, 256]               0
#          MaxPool2d-6         [-1, 40, 128, 128]               0
#             Conv2d-7         [-1, 50, 128, 128]          50,050
#               ReLU-8         [-1, 50, 128, 128]               0
#          MaxPool2d-9           [-1, 50, 64, 64]               0
#            Conv2d-10           [-1, 60, 64, 64]          75,060
#              ReLU-11           [-1, 60, 64, 64]               0
#         MaxPool2d-12           [-1, 60, 64, 64]               0
#            Conv2d-13          [-1, 100, 64, 64]         150,100
# ...

# %% [markdown]
# ## Training Loop

# %%
#Adapted from https://github.com/usuyama/pytorch-unet

import torch
import torch.optim as optim
from torch.optim import lr_scheduler
import time
import copy
from collections import defaultdict
import torch.nn.functional as F
import torch.nn as nn

def calc_loss_dense(pred, target, metrics):
    criterion = nn.MSELoss()
    loss = criterion(pred, target)
    metrics['loss'] += loss.data.cpu().numpy() * target.size(0)

    return loss

def calc_loss_sparse(pred, target, samples, metrics, num_samples):
    criterion = nn.MSELoss()
    loss = criterion(samples*pred, samples*target)*(256**2)/num_samples
    metrics['loss'] += loss.data.cpu().numpy() * target.size(0)

    return loss

def print_metrics(metrics, epoch_samples, phase):
    outputs1 = []
    outputs2 = []
    for k in metrics.keys():
        outputs1.append("{}: {:4f}".format(k, metrics[k] / (epoch_samples*256**2)))

    print("{}: {}".format(phase, ", ".join(outputs1)))

def train_model(model, optimizer, scheduler, num_epochs=50, WNetPhase="firstU", targetType="dense", num_samples=300):
    # WNetPhase: traine first U and freez second ("firstU"), or vice verse ("secondU").
    # targetType: train against dense images ("dense") or sparse measurements ("sparse")
    best_model_wts = copy.deepcopy(model.state_dict())
    best_loss = 1e10

    for epoch in range(num_epochs):
        print('Epoch {}/{}'.format(epoch, num_epochs - 1))
        print('-' * 10)

        since = time.time()

        # Each epoch has a training and validation phase
        for phase in ['train', 'val']:
            if phase == 'train':
                scheduler.step()
                for param_group in optimizer.param_groups:
                    print("learning rate", param_group['lr'])

                model.train()  # Set model to training mode
            else:
                model.eval()   # Set model to evaluate mode

            metrics = defaultdict(float)
            epoch_samples = 0

            if targetType=="dense":
                for inputs, targets in dataloaders[phase]:
                    inputs = inputs.to(device)
                    targets = targets.to(device)

                    # zero the parameter gradients
                    optimizer.zero_grad()

                    # forward
                    # track history if only in train
                    with torch.set_grad_enabled(phase == 'train'):
                        [outputs1,outputs2] = model(inputs)
                        if WNetPhase=="firstU":
                            loss = calc_loss_dense(outputs1, targets, metrics)
                        else:
                            loss = calc_loss_dense(outputs2, targets, metrics)

                        # backward + optimize only if in training phase
                        if phase == 'train':
                            loss.backward()
                            optimizer.step()

                    # statistics
                    epoch_samples += inputs.size(0)
            elif targetType=="sparse":
                for inputs, targets, samples in dataloaders[phase]:
                    inputs = inputs.to(device)
                    targets = targets.to(device)
                    samples = samples.to(device)

                    # zero the parameter gradients
                    optimizer.zero_grad()

                    # forward
                    # track history if only in train
                    with torch.set_grad_enabled(phase == 'train'):
                        [outputs1,outputs2] = model(inputs)
                        if WNetPhase=="firstU":
                            loss = calc_loss_sparse(outputs1, targets, samples, metrics, num_samples)
                        else:
                            loss = calc_loss_sparse(outputs2, targets, samples, metrics, num_samples)

                        # backward + optimize only if in training phase
                        if phase == 'train':
                            loss.backward()
                            optimizer.step()

                    # statistics
                    epoch_samples += inputs.size(0)

            print_metrics(metrics, epoch_samples, phase)
            epoch_loss = metrics['loss'] / epoch_samples

            # deep copy the model
            if phase == 'val' and epoch_loss < best_loss:
                print("saving best model")
                best_loss = epoch_loss
                best_model_wts = copy.deepcopy(model.state_dict())

        time_elapsed = time.time() - since
        print('{:.0f}m {:.0f}s'.format(time_elapsed // 60, time_elapsed % 60))

    print('Best val loss: {:4f}'.format(best_loss))

    # load best model weights
    model.load_state_dict(best_model_wts)
    return model

# %% [markdown]
# ## Training First UNet

# %%
import torch
import torch.optim as optim
from torch.optim import lr_scheduler
import time
import copy

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print(device)


optimizer_ft = optim.Adam(filter(lambda p: p.requires_grad, model.parameters()), lr=1e-4)

exp_lr_scheduler = lr_scheduler.StepLR(optimizer_ft, step_size=30, gamma=0.1)

model = train_model(model, optimizer_ft, exp_lr_scheduler)
# Out:
# cuda:0
# Epoch 0/49
# ----------
# learning rate 0.0001
# train: loss: 0.007781
# val: loss: 0.004828
# saving best model
# 8m 34s
# Epoch 1/49
# ----------
# learning rate 0.0001
# train: loss: 0.004372
# val: loss: 0.003894
# saving best model
# 8m 53s
# Epoch 2/49
# ----------
# learning rate 0.0001
# train: loss: 0.003751
# val: loss: 0.003435
# saving best model
# 8m 54s
# Epoch 3/49
# ----------
# learning rate 0.0001
# train: loss: 0.003358
# val: loss: 0.003169
# saving best model
# 8m 56s
# Epoch 4/49
# ----------
# learning rate 0.0001
# train: loss: 0.003104
# val: loss: 0.002889
# saving best model
# 8m 57s
# Epoch 5/49
# ----------
# learning rate 0.0001
# train: loss: 0.002867
# val: loss: 0.002830
# saving best model
# 8m 59s
# Epoch 6/49
# ----------
# learning rate 0.0001
# train: loss: 0.002511
# val: loss: 0.002486
# saving best model
# 9m 0s
# Epoch 7/49
# ----------
# learning rate 0.0001
# train: loss: 0.002317
# val: loss: 0.002421
# saving best model
# 9m 1s
# ...

# %% [markdown]
# ## Create Directory For Saving the Model and Examples

# %%
import os
try: 
    os.mkdir('RadioWNet_s_randSim_miss4Build_Thr2') 
except OSError as error: 
    print(error)

# %% [markdown]
# ## Save First U Model For Inference

# %%
torch.save(model.state_dict(), 'RadioWNet_s_randSim_miss4Build_Thr2/Trained_Model_FirstU.pt')

# %% [markdown]
# ## Load Second U Model For Inference

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model = modules.RadioWNet(inputs=3, phase="firstU")
model.load_state_dict(torch.load('RadioWNet_s_randSim_miss4Build_Thr2/Trained_Model_FirstU.pt'))
model.to(device)
# Out:
# RadioWNet(
#   (layer00): Sequential(
#     (0): Conv2d(3, 6, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU(inplace=True)
#     (2): MaxPool2d(kernel_size=1, stride=1, padding=0, dilation=1, ceil_mode=False)
#   )
#   (layer0): Sequential(
#     (0): Conv2d(6, 40, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     (1): ReLU(inplace=True)
#     (2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (layer1): Sequential(
#     (0): Conv2d(40, 50, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     (1): ReLU(inplace=True)
#     (2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (layer10): Sequential(
#     (0): Conv2d(50, 60, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     (1): ReLU(inplace=True)
#     (2): MaxPool2d(kernel_size=1, stride=1, padding=0, dilation=1, ceil_mode=False)
#   )
#   (layer2): Sequential(
# ...

# %% [markdown]
# ## Second U Module

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model =modules.RadioWNet(inputs=3, phase="secondU")
model.load_state_dict(torch.load('RadioWNet_s_randSim_miss4Build_Thr2/Trained_Model_FirstU.pt'))
model.to(device)
# Out:
# RadioWNet(
#   (layer00): Sequential(
#     (0): Conv2d(3, 6, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU(inplace=True)
#     (2): MaxPool2d(kernel_size=1, stride=1, padding=0, dilation=1, ceil_mode=False)
#   )
#   (layer0): Sequential(
#     (0): Conv2d(6, 40, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     (1): ReLU(inplace=True)
#     (2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (layer1): Sequential(
#     (0): Conv2d(40, 50, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     (1): ReLU(inplace=True)
#     (2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (layer10): Sequential(
#     (0): Conv2d(50, 60, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     (1): ReLU(inplace=True)
#     (2): MaxPool2d(kernel_size=1, stride=1, padding=0, dilation=1, ceil_mode=False)
#   )
#   (layer2): Sequential(
# ...

# %% [markdown]
# ## Training Scond UNet

# %%
import torch
import torch.optim as optim
from torch.optim import lr_scheduler
import time
import copy

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print(device)


optimizer_ft = optim.Adam(filter(lambda p: p.requires_grad, model.parameters()), lr=1e-4)

exp_lr_scheduler = lr_scheduler.StepLR(optimizer_ft, step_size=30, gamma=0.1)

model = train_model(model, optimizer_ft, exp_lr_scheduler, WNetPhase="secondU")
# Out:
# cuda:0
# Epoch 0/49
# ----------
# learning rate 0.0001
# train: loss: 0.002165
# val: loss: 0.002160
# saving best model
# 8m 32s
# Epoch 1/49
# ----------
# learning rate 0.0001
# train: loss: 0.001877
# val: loss: 0.002137
# saving best model
# 8m 30s
# Epoch 2/49
# ----------
# learning rate 0.0001
# train: loss: 0.001824
# val: loss: 0.002094
# saving best model
# 8m 30s
# Epoch 3/49
# ----------
# learning rate 0.0001
# train: loss: 0.001786
# val: loss: 0.002031
# saving best model
# 8m 30s
# Epoch 4/49
# ----------
# learning rate 0.0001
# train: loss: 0.001746
# val: loss: 0.002035
# 8m 29s
# Epoch 5/49
# ----------
# learning rate 0.0001
# train: loss: 0.001706
# val: loss: 0.001996
# saving best model
# 8m 30s
# Epoch 6/49
# ----------
# learning rate 0.0001
# train: loss: 0.001668
# val: loss: 0.001964
# saving best model
# 8m 29s
# Epoch 7/49
# ----------
# learning rate 0.0001
# train: loss: 0.001643
# val: loss: 0.001958
# saving best model
# 8m 29s
# Epoch 8/49
# ...

# %% [markdown]
# ## Save Second U Model For Inference

# %%
torch.save(model.state_dict(), 'RadioWNet_s_randSim_miss4Build_Thr2/Trained_Model_SecondU.pt')

# %% [markdown]
# ## Load Second U Model For Inference

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model = modules.RadioWNet(inputs=3, phase="secondU")
model.load_state_dict(torch.load('RadioWNet_s_randSim_miss4Build_Thr2/Trained_Model_SecondU.pt'))
model.to(device)
# Out:
# RadioWNet(
#   (layer00): Sequential(
#     (0): Conv2d(3, 6, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU(inplace=True)
#     (2): MaxPool2d(kernel_size=1, stride=1, padding=0, dilation=1, ceil_mode=False)
#   )
#   (layer0): Sequential(
#     (0): Conv2d(6, 40, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     (1): ReLU(inplace=True)
#     (2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (layer1): Sequential(
#     (0): Conv2d(40, 50, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     (1): ReLU(inplace=True)
#     (2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (layer10): Sequential(
#     (0): Conv2d(50, 60, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     (1): ReLU(inplace=True)
#     (2): MaxPool2d(kernel_size=1, stride=1, padding=0, dilation=1, ceil_mode=False)
#   )
#   (layer2): Sequential(
# ...

# %% [markdown]
# ## Test Accuracy

# %%
import torch
import torch.optim as optim
from torch.optim import lr_scheduler
import time
import copy
from collections import defaultdict
import torch.nn.functional as F
import torch.nn as nn

def calc_loss_test(pred1, pred2, target, metrics, error="MSE"):
    criterion = nn.MSELoss()
    if error=="MSE":
        loss1 = criterion(pred1, target)
        loss2 = criterion(pred2, target)
    else:
        loss1 = criterion(pred1, target)/criterion(target, 0*target)
        loss2 = criterion(pred2, target)/criterion(target, 0*target)
    metrics['loss first U'] += loss1.data.cpu().numpy() * target.size(0)
    metrics['loss second U'] += loss2.data.cpu().numpy() * target.size(0)

    return [loss1,loss2]

def print_metrics_test(metrics, epoch_samples, error):
    outputs = []
    if error=="MSE":
        for k in metrics.keys():
            outputs.append("{}: {:4f}".format(k, metrics[k] / (epoch_samples*256**2)))
    else:
        for k in metrics.keys():
            outputs.append("{}: {:4f}".format(k, metrics[k] / epoch_samples))
    print("{}: {}".format("Test"+" "+error, ", ".join(outputs)))

def test_loss(model, error="MSE", dataset="coarse"):
    # dataset is "coarse" or "fine".
    since = time.time()
    model.eval()   # Set model to evaluate mode
    metrics = defaultdict(float)
    epoch_samples = 0
    if dataset=="coarse":
        for inputs, targets in DataLoader(Radio_test, batch_size=batch_size, shuffle=True, num_workers=1):
            inputs = inputs.to(device)
            targets = targets.to(device)
            # do not track history if only in train
            with torch.set_grad_enabled(False):
                [outputs1,outputs2] = model(inputs)
                [loss1,loss2] = calc_loss_test(outputs1, outputs2, targets, metrics, error)
                epoch_samples += inputs.size(0)
    elif dataset=="fine":  
        for inputs, targets, samples in DataLoader(Radio_test, batch_size=batch_size, shuffle=True, num_workers=1):
            inputs = inputs.to(device)
            targets = targets.to(device)
            # do not track history if only in train
            with torch.set_grad_enabled(False):
                [outputs1,outputs2] = model(inputs)
                [loss1,loss2] = calc_loss_test(outputs1, outputs2, targets, metrics, error)
                epoch_samples += inputs.size(0)
    print_metrics_test(metrics, epoch_samples, error)
    #test_loss1 = metrics['loss U'] / epoch_samples
    #test_loss2 = metrics['loss W'] / epoch_samples
    time_elapsed = time.time() - since
    print('{:.0f}m {:.0f}s'.format(time_elapsed // 60, time_elapsed % 60))

# %% [markdown]
# ### MSE Accuracy on DPM

# %%
test_loss(model,error="MSE")
# Out:
# Test MSE: loss first U: 0.002318, loss second U: 0.001970
# 0m 51s

# %% [markdown]
# ### NMSE Accuracy on DPM

# %%
test_loss(model,error="NMSE")
# Out:
# Test NMSE: loss first U: 0.046155, loss second U: 0.039003
# 0m 51s

# %% [markdown]
# ## Sampled IRT4 Data Loader

# %%
Radio_train = loaders.RadioUNet_s_sprseIRT4(phase="train", simulation="IRT4", cityMap="missing", missing=4, data_samples=600)
Radio_val = loaders.RadioUNet_s_sprseIRT4(phase="val", simulation="IRT4", cityMap="missing", missing=4, data_samples=600)
Radio_test = loaders.RadioUNet_s_sprseIRT4(phase="test", simulation="IRT4", cityMap="missing", missing=4, data_samples=600)

image_datasets = {
    'train': Radio_train, 'val': Radio_val
}

batch_size = 15

dataloaders = {
    'train': DataLoader(Radio_train, batch_size=batch_size, shuffle=True, num_workers=1),
    'val': DataLoader(Radio_val, batch_size=batch_size, shuffle=True, num_workers=1)
}

# %% [markdown]
# ## Test Zero-Shot Accuracy On IRT4

# %% [markdown]
# ### MSE Accuracy on DPM

# %%
test_loss(model,error="MSE", dataset="fine")
# Out:
# Test MSE: loss first U: 0.002208, loss second U: 0.001911
# 0m 3s

# %% [markdown]
# ### NMSE Accuracy on DPM

# %%
test_loss(model,error="NMSE", dataset="fine")
# Out:
# Test NMSE: loss first U: 0.047710, loss second U: 0.041736
# 0m 1s

# %% [markdown]
# ## Training Sampled IRT4 UNet

# %%
import torch
import torch.optim as optim
from torch.optim import lr_scheduler
import time
import copy

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print(device)


optimizer_ft = optim.Adam(filter(lambda p: p.requires_grad, model.parameters()), lr=1e-4)

exp_lr_scheduler = lr_scheduler.StepLR(optimizer_ft, step_size=30, gamma=0.1)

model = train_model(model, optimizer_ft, exp_lr_scheduler, WNetPhase="secondU", targetType="sparse", num_samples=600)
# Out:
# cuda:0
# Epoch 0/49
# ----------
# learning rate 0.0001
# train: loss: 0.001354
# val: loss: 0.001560
# saving best model
# 0m 20s
# Epoch 1/49
# ----------
# learning rate 0.0001
# train: loss: 0.001313
# val: loss: 0.001575
# 0m 20s
# Epoch 2/49
# ----------
# learning rate 0.0001
# train: loss: 0.001282
# val: loss: 0.001598
# 0m 20s
# Epoch 3/49
# ----------
# learning rate 0.0001
# train: loss: 0.001235
# val: loss: 0.001514
# saving best model
# 0m 20s
# Epoch 4/49
# ----------
# learning rate 0.0001
# train: loss: 0.001227
# val: loss: 0.001561
# 0m 20s
# Epoch 5/49
# ----------
# learning rate 0.0001
# train: loss: 0.001222
# val: loss: 0.001690
# 0m 20s
# Epoch 6/49
# ----------
# learning rate 0.0001
# train: loss: 0.001217
# val: loss: 0.001736
# 0m 20s
# Epoch 7/49
# ----------
# learning rate 0.0001
# train: loss: 0.001193
# val: loss: 0.001728
# 0m 20s
# Epoch 8/49
# ----------
# learning rate 0.0001
# train: loss: 0.001168
# val: loss: 0.001672
# 0m 20s
# Epoch 9/49
# ...

# %% [markdown]
# ## Save Adaptation to IRT4 Model For Inference

# %%
torch.save(model.state_dict(), 'RadioWNet_s_randSim_miss4Build_Thr2/Trained_Model_IRT4.pt')

# %% [markdown]
# ## Load Adaptation to IRT4 Model For Inference

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model = modules.RadioWNet(inputs=3, phase="secondU")
model.load_state_dict(torch.load('RadioWNet_s_randSim_miss4Build_Thr2/Trained_Model_IRT4.pt'))
model.to(device)
# Out:
# RadioWNet(
#   (layer00): Sequential(
#     (0): Conv2d(3, 6, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU(inplace=True)
#     (2): MaxPool2d(kernel_size=1, stride=1, padding=0, dilation=1, ceil_mode=False)
#   )
#   (layer0): Sequential(
#     (0): Conv2d(6, 40, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     (1): ReLU(inplace=True)
#     (2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (layer1): Sequential(
#     (0): Conv2d(40, 50, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     (1): ReLU(inplace=True)
#     (2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (layer10): Sequential(
#     (0): Conv2d(50, 60, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     (1): ReLU(inplace=True)
#     (2): MaxPool2d(kernel_size=1, stride=1, padding=0, dilation=1, ceil_mode=False)
#   )
#   (layer2): Sequential(
# ...

# %% [markdown]
# ## Test Adaptation to IRT4 Accuracy On IRT4

# %% [markdown]
# ### MSE Accuracy on IRT4

# %%
test_loss(model,error="MSE", dataset="fine")
# Out:
# Test MSE: loss first U: 0.002080, loss second U: 0.001686
# 0m 2s

# %% [markdown]
# ### NMSE Accuracy on IRT4

# %%
test_loss(model,error="NMSE", dataset="fine")
# Out:
# Test NMSE: loss first U: 0.046140, loss second U: 0.037260
# 0m 2s

# %% [markdown]
# # Save Image Examples

# %% [markdown]
# ## Create Directory For Saving Examples

# %%
import os
try: 
    os.mkdir('RadioWNet_s_randSim_miss4Build_Thr2/Examples') 
except OSError as error: 
    print(error)
# Out:
# [Errno 17] File exists: 'RadioWNet_s_randSim_miss4Build_Thr2/Examples'

# %% [markdown]
# ## Save Examples IRT4

# %%
maps_inds=np.arange(0,700,1,dtype=np.int16)
#Standard determenistic "random" shuffle of the maps:
np.random.seed(42)
np.random.shuffle(maps_inds)
            
from PIL import Image
for mapp in range(1,99):
    name00=str(mapp)
    name0=str(maps_inds[600+mapp])
    Radio_test2 = loaders.RadioUNet_s_sprseIRT4(maps_inds=maps_inds, phase="custom", 
                                               ind1=600+mapp, ind2=600+mapp, 
                                               simulation="IRT4", cityMap="missing", missing=4, data_samples=600)
    
   
    ii=0
    for inputs, target, samps in DataLoader(Radio_test2, batch_size=1, shuffle=False, num_workers=0):
        ii=ii+1
        inputs = inputs.to(device)
        target = target.to(device)
        pred1, pred = model(inputs)
        pred = (pred.detach().cpu().numpy()).astype(np.uint8)
        builds=inputs.detach().cpu().numpy()
        builds=builds[0][0]
        inputs = (inputs.detach().cpu().numpy()).astype(np.uint8)
        indB=builds!=0
        im=np.zeros([256,256,3])
        #imT=np.zeros([256,256,3])
        im[:,:,0] = (pred[0][0])
        im[:,:,1] = (pred[0][0])
        im[:,:,2] = (pred[0][0])
        im[indB,2]=130
        #imT=im
        ind0=inputs[0][2]!=0
        ind1=inputs[0][2]>=100 
        im[ind0,1]=0
        im[ind0,0]=255
        im[ind0,2]=20
        im[ind1,0]=80
        im[ind1,2]=0
        im = Image.fromarray(im.astype(np.uint8))

        name=str(ii)
        #file_name="buildC_carsN_simulD_DMP_samplesN/%spredict.png" %name
        file_name="RadioWNet_s_randSim_miss4Build_Thr2/Examples/" +name00+ "_"+name0+ "_"+ name + "IRT4_predict.png" 
        im.save(file_name)
        #file_name="%spredict.png" %name
        im = Image.fromarray(255*inputs[0][2])
        file_name="RadioWNet_s_randSim_miss4Build_Thr2/Examples/" +name00+ "_"+name0+ "_"+ name + "IRT4_samples.png" 
        im.save(file_name)
        Gtruth = (target.detach().cpu().numpy() )#.astype(np.uint8)
        im=np.zeros([256,256,3])
        im[:,:,0]=Gtruth[0][0]
        im[:,:,1]=Gtruth[0][0]
        im[:,:,2]=Gtruth[0][0]
        im[indB,2]=130
        im = Image.fromarray(im.astype(np.uint8))
        #file_name="buildC_carsN_simulD_DMP_samplesN/%starget.png" %name
        file_name="RadioWNet_s_randSim_miss4Build_Thr2/Examples/" +name00+ "_"+name0+ "_"+ name + "IRT4_target.png"
        #file_name="%starget.png" %name
        im.save(file_name)

# %% [markdown]
# ## Save Image Examples for DPM Data

# %% [markdown]
# ### Load DPM Model For Inference

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model = modules.RadioWNet(inputs=3, phase="secondU")
model.load_state_dict(torch.load('RadioWNet_s_randSim_miss4Build_Thr2/Trained_Model_SecondU.pt'))
model.to(device)
# Out:
# RadioWNet(
#   (layer00): Sequential(
#     (0): Conv2d(3, 6, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU(inplace=True)
#     (2): MaxPool2d(kernel_size=1, stride=1, padding=0, dilation=1, ceil_mode=False)
#   )
#   (layer0): Sequential(
#     (0): Conv2d(6, 40, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     (1): ReLU(inplace=True)
#     (2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (layer1): Sequential(
#     (0): Conv2d(40, 50, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     (1): ReLU(inplace=True)
#     (2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (layer10): Sequential(
#     (0): Conv2d(50, 60, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     (1): ReLU(inplace=True)
#     (2): MaxPool2d(kernel_size=1, stride=1, padding=0, dilation=1, ceil_mode=False)
#   )
#   (layer2): Sequential(
# ...

# %% [markdown]
# ## Save Examples Random Coarse Simulation

# %%
maps_inds=np.arange(0,700,1,dtype=np.int16)
#Standard determenistic "random" shuffle of the maps:
np.random.seed(42)
np.random.shuffle(maps_inds)
            
from PIL import Image
for mapp in range(1,99):
    name00=str(mapp)
    name0=str(maps_inds[600+mapp])
    Radio_test2 = loaders.RadioUNet_s(maps_inds=maps_inds, phase="custom", 
                                               ind1=600+mapp, ind2=600+mapp, 
                                               simulation="rand", cityMap="missing", missing=4)
    
   
    ii=0
    for inputs, target in DataLoader(Radio_test2, batch_size=1, shuffle=False, num_workers=0):
        ii=ii+1
        if ii>2:
            break
        inputs = inputs.to(device)
        target = target.to(device)
        pred1, pred = model(inputs)
        pred = (pred.detach().cpu().numpy()).astype(np.uint8)
        builds=inputs.detach().cpu().numpy()
        builds=builds[0][0]
        inputs = (inputs.detach().cpu().numpy()).astype(np.uint8)
        indB=builds!=0
        im=np.zeros([256,256,3])
        #imT=np.zeros([256,256,3])
        im[:,:,0] = (pred[0][0])
        im[:,:,1] = (pred[0][0])
        im[:,:,2] = (pred[0][0])
        im[indB,2]=130
        #imT=im
        ind0=inputs[0][2]!=0
        ind1=inputs[0][2]>=100 
        im[ind0,1]=0
        im[ind0,0]=255
        im[ind0,2]=20
        im[ind1,0]=80
        im[ind1,2]=0
        im = Image.fromarray(im.astype(np.uint8))

        name=str(ii)
        #file_name="buildC_carsN_simulD_DMP_samplesN/%spredict.png" %name
        file_name="RadioWNet_s_randSim_miss4Build_Thr2/Examples/" +name00+ "_"+name0+ "_"+ name + "coarse_predict.png" 
        im.save(file_name)
        #file_name="%spredict.png" %name
        im = Image.fromarray(255*inputs[0][2])
        file_name="RadioWNet_s_randSim_miss4Build_Thr2/Examples/" +name00+ "_"+name0+ "_"+ name + "coarse_samples.png" 
        im.save(file_name)
        Gtruth = (target.detach().cpu().numpy() )#.astype(np.uint8)
        im=np.zeros([256,256,3])
        im[:,:,0]=Gtruth[0][0]
        im[:,:,1]=Gtruth[0][0]
        im[:,:,2]=Gtruth[0][0]
        im[indB,2]=130
        im = Image.fromarray(im.astype(np.uint8))
        #file_name="buildC_carsN_simulD_DMP_samplesN/%starget.png" %name
        file_name="RadioWNet_s_randSim_miss4Build_Thr2/Examples/" +name00+ "_"+name0+ "_"+ name + "coarse_target.png"
        #file_name="%starget.png" %name
        im.save(file_name)

# %% [markdown]
# ## Show examples

# %%
fig, axarr = plt.subplots(2,2, figsize=(8, 8))


im=io.imread("RadioWNet_s_randSim_miss4Build_Thr2/Examples/17_187_1coarse_target.png")
fig.add_subplot(2, 2, 1)
plt.imshow(im)
axarr[0, 0].set_title('Target Coarse')

im=io.imread("RadioWNet_s_randSim_miss4Build_Thr2/Examples/17_187_1coarse_predict.png")
fig.add_subplot(2, 2, 2)
plt.imshow(im)
axarr[0, 1].set_title('Predicted Coarse')

im=io.imread("RadioWNet_s_randSim_miss4Build_Thr2/Examples/17_187_1IRT4_target.png")
fig.add_subplot(2, 2, 3)
plt.imshow(im)
axarr[1, 0].set_title('Target IRT2')

im=io.imread("RadioWNet_s_randSim_miss4Build_Thr2/Examples/17_187_1IRT4_predict.png")
fig.add_subplot(2, 2, 4)
plt.imshow(im)
axarr[1, 1].set_title('Predicted IRT2')
# Out:
# Text(0.5, 1.0, 'Predicted IRT2')

# %%
fig, axarr = plt.subplots(2,2, figsize=(8, 8))


im=io.imread("RadioWNet_s_randSim_miss4Build_Thr2/Examples/41_508_2coarse_target.png")
fig.add_subplot(2, 2, 1)
plt.imshow(im)
axarr[0, 0].set_title('Target Coarse')

im=io.imread("RadioWNet_s_randSim_miss4Build_Thr2/Examples/41_508_2coarse_predict.png")
fig.add_subplot(2, 2, 2)
plt.imshow(im)
axarr[0, 1].set_title('Predicted Coase')

im=io.imread("RadioWNet_s_randSim_miss4Build_Thr2/Examples/41_508_2IRT4_target.png")
fig.add_subplot(2, 2, 3)
plt.imshow(im)
axarr[1, 0].set_title('Target IRT2')

im=io.imread("RadioWNet_s_randSim_miss4Build_Thr2/Examples/41_508_2IRT4_predict.png")
fig.add_subplot(2, 2, 4)
plt.imshow(im)
axarr[1, 1].set_title('Predicted IRT2')
# Out:
# Text(0.5, 1.0, 'Predicted IRT2')

# %%
fig, axarr = plt.subplots(2,2, figsize=(8, 8))


im=io.imread("RadioWNet_s_randSim_miss4Build_Thr2/Examples/31_476_2coarse_target.png")
fig.add_subplot(2, 2, 1)
plt.imshow(im)
axarr[0, 0].set_title('Target DPM')

im=io.imread("RadioWNet_s_randSim_miss4Build_Thr2/Examples/31_476_2coarse_predict.png")
fig.add_subplot(2, 2, 2)
plt.imshow(im)
axarr[0, 1].set_title('Predicted DPM')

im=io.imread("RadioWNet_s_randSim_miss4Build_Thr2/Examples/31_476_2IRT4_target.png")
fig.add_subplot(2, 2, 3)
plt.imshow(im)
axarr[1, 0].set_title('Target IRT2')

im=io.imread("RadioWNet_s_randSim_miss4Build_Thr2/Examples/31_476_2IRT4_predict.png")
fig.add_subplot(2, 2, 4)
plt.imshow(im)
axarr[1, 1].set_title('Predicted IRT2')
# Out:
# Text(0.5, 1.0, 'Predicted IRT2')

# %% [markdown]
# # Save Image Examples

# %% [markdown]
# ## Create Directory For Saving Examples

# %%
import os
try: 
    os.mkdir('RadioWNet_s_randSim_miss4Build_Thr2/Examples') 
except OSError as error: 
    print(error)
# Out:
# [Errno 17] File exists: 'RadioWNet_s_randSim_miss4Build_Thr2/Examples'

# %% [markdown]
# ## Load the two models

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model_coarse = modules.RadioWNet(inputs=3, phase="secondU")
model_coarse.load_state_dict(torch.load('RadioWNet_s_randSim_miss4Build_Thr2/Trained_Model_SecondU.pt'))
model_coarse.to(device)

model_IRT4 = modules.RadioWNet(inputs=3, phase="secondU")
model_IRT4.load_state_dict(torch.load('RadioWNet_s_randSim_miss4Build_Thr2/Trained_Model_IRT4.pt'))
model_IRT4.to(device)
# Out:
# RadioWNet(
#   (layer00): Sequential(
#     (0): Conv2d(3, 6, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU(inplace=True)
#     (2): MaxPool2d(kernel_size=1, stride=1, padding=0, dilation=1, ceil_mode=False)
#   )
#   (layer0): Sequential(
#     (0): Conv2d(6, 40, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     (1): ReLU(inplace=True)
#     (2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (layer1): Sequential(
#     (0): Conv2d(40, 50, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     (1): ReLU(inplace=True)
#     (2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (layer10): Sequential(
#     (0): Conv2d(50, 60, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     (1): ReLU(inplace=True)
#     (2): MaxPool2d(kernel_size=1, stride=1, padding=0, dilation=1, ceil_mode=False)
#   )
#   (layer2): Sequential(
# ...

# %% [markdown]
# ## Save Examples

# %%
maps_inds=np.arange(0,700,1,dtype=np.int16)
#Standard determenistic "random" shuffle of the maps:
np.random.seed(42)
np.random.shuffle(maps_inds)
            
from PIL import Image
for mapp in range(1,99):
    name00=str(mapp)
    name0=str(maps_inds[600+mapp])
    #Radio_test_coarse = loaders.RadioUNet_s(maps_inds=maps_inds, phase="custom", 
    #                                           ind1=600+mapp, ind2=600+mapp, 
    #                                           simulation="rand", cityMap="missing", missing=4)
    Radio_test_IRT4 = loaders.RadioUNet_s_sprseIRT4(maps_inds=maps_inds, phase="custom", 
                                               ind1=600+mapp, ind2=600+mapp, 
                                               simulation="IRT4", cityMap="missing", missing=4, data_samples=600)
    
   
    ii=0
    for inputs, target, samps in DataLoader(Radio_test_IRT4, batch_size=1, shuffle=False, num_workers=0):
        ii=ii+1
        if ii>2:
            break
        inputs = inputs.to(device)
        target = target.to(device)
        pred1, pred_IRT4 = model_IRT4(inputs)
        pred1, pred_coarse = model_coarse(inputs)
        pred_IRT4 = (pred_IRT4.detach().cpu().numpy()).astype(np.uint8)
        pred_coarse = (pred_coarse.detach().cpu().numpy()).astype(np.uint8)
        builds=inputs.detach().cpu().numpy()
        builds=builds[0][0]
        inputs = (inputs.detach().cpu().numpy()).astype(np.uint8)
        indB=builds!=0
        
        # IRT4 prediction:
        im=np.zeros([256,256,3])
        #imT=np.zeros([256,256,3])
        im[:,:,0] = (pred_IRT4[0][0])
        im[:,:,1] = (pred_IRT4[0][0])
        im[:,:,2] = (pred_IRT4[0][0])
        im[indB,2]=130
        #imT=im
        ind0=inputs[0][2]!=0
        ind1=inputs[0][2]>=100 
        im[ind0,1]=0
        im[ind0,0]=255
        im[ind0,2]=20
        im[ind1,0]=80
        im[ind1,2]=0
        im = Image.fromarray(im.astype(np.uint8))
        name=str(ii)
        file_name="RadioWNet_s_randSim_miss4Build_Thr2/Examples/" +name00+ "_"+name0+ "_"+ name + "IRT4_predict.png" 
        im.save(file_name)
        
        # Coarse simulation prediction:
        im=np.zeros([256,256,3])
        #imT=np.zeros([256,256,3])
        im[:,:,0] = (pred_coarse[0][0])
        im[:,:,1] = (pred_coarse[0][0])
        im[:,:,2] = (pred_coarse[0][0])
        im[indB,2]=130
        #imT=im
        ind0=inputs[0][2]!=0
        ind1=inputs[0][2]>=100 
        im[ind0,1]=0
        im[ind0,0]=255
        im[ind0,2]=20
        im[ind1,0]=80
        im[ind1,2]=0
        im = Image.fromarray(im.astype(np.uint8))
        file_name="RadioWNet_s_randSim_miss4Build_Thr2/Examples/" +name00+ "_"+name0+ "_"+ name + "coarse_predict.png" 
        im.save(file_name)
        
        #Samples image:
        im = Image.fromarray(255*inputs[0][2])
        file_name="RadioWNet_s_randSim_miss4Build_Thr2/Examples/" +name00+ "_"+name0+ "_"+ name + "_samples.png" 
        im.save(file_name)
        
        #Target radio map image:
        Gtruth = (target.detach().cpu().numpy() )#.astype(np.uint8)
        im=np.zeros([256,256,3])
        im[:,:,0]=Gtruth[0][0]
        im[:,:,1]=Gtruth[0][0]
        im[:,:,2]=Gtruth[0][0]
        im[indB,2]=130
        im = Image.fromarray(im.astype(np.uint8))
        #file_name="buildC_carsN_simulD_DMP_samplesN/%starget.png" %name
        file_name="RadioWNet_s_randSim_miss4Build_Thr2/Examples/" +name00+ "_"+name0+ "_"+ name + "IRT4_target.png"
        #file_name="%starget.png" %name
        im.save(file_name)

# %% [markdown]
# ## Show examples

# %%
fig, axarr = plt.subplots(1,3, figsize=(24, 8))

im=io.imread("RadioWNet_s_randSim_miss4Build_Thr2/Examples/11_64_1IRT4_target.png")
fig.add_subplot(1, 3, 1)
plt.imshow(im)
axarr[0].set_title('Target IRT2')


im=io.imread("RadioWNet_s_randSim_miss4Build_Thr2/Examples/11_64_1coarse_predict.png")
fig.add_subplot(1, 3, 2)
plt.imshow(im)
axarr[1].set_title('Predicted Coarse')



im=io.imread("RadioWNet_s_randSim_miss4Build_Thr2/Examples/11_64_1IRT4_predict.png")
fig.add_subplot(1, 3, 3)
plt.imshow(im)
axarr[2].set_title('Predicted IRT2')
# Out:
# Text(0.5, 1.0, 'Predicted IRT2')

# %%
fig, axarr = plt.subplots(1,3, figsize=(24, 8))

im=io.imread("RadioWNet_s_randSim_miss4Build_Thr2/Examples/17_187_2IRT4_target.png")
fig.add_subplot(1, 3, 1)
plt.imshow(im)
axarr[0].set_title('Target IRT2')


im=io.imread("RadioWNet_s_randSim_miss4Build_Thr2/Examples/17_187_2coarse_predict.png")
fig.add_subplot(1, 3, 2)
plt.imshow(im)
axarr[1].set_title('Predicted Coarse')



im=io.imread("RadioWNet_s_randSim_miss4Build_Thr2/Examples/17_187_2IRT4_predict.png")
fig.add_subplot(1, 3, 3)
plt.imshow(im)
axarr[2].set_title('Predicted IRT2')
# Out:
# Text(0.5, 1.0, 'Predicted IRT2')

# %%
fig, axarr = plt.subplots(1,3, figsize=(24, 8))

im=io.imread("RadioWNet_s_randSim_miss4Build_Thr2/Examples/31_476_2IRT4_target.png")
fig.add_subplot(1, 3, 1)
plt.imshow(im)
axarr[0].set_title('Target IRT2')


im=io.imread("RadioWNet_s_randSim_miss4Build_Thr2/Examples/31_476_2coarse_predict.png")
fig.add_subplot(1, 3, 2)
plt.imshow(im)
axarr[1].set_title('Predicted Coarse')



im=io.imread("RadioWNet_s_randSim_miss4Build_Thr2/Examples/31_476_2IRT4_predict.png")
fig.add_subplot(1, 3, 3)
plt.imshow(im)
axarr[2].set_title('Predicted IRT2')
# Out:
# Text(0.5, 1.0, 'Predicted IRT2')
